# %% [markdown]
# # Notebook with minimal example to run hpo glue Optimizers on Benchmarks

# %% [markdown]
# <a href="https://githubtocolab.com/Sohambasu07/hpo_glue/blob/main/examples/glue_demo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %% [markdown]
# ## Install hpo glue

# %%
# !git clone https://github.com/Sohambasu07/hpo_glue.git
# !cd hpo_glue
# !python -m pip install -e .

# %% [markdown]
# ## Print the list of available example benchmarks and optimizers

# %%
from lib import BENCHMARKS, OPTIMIZERS

print(OPTIMIZERS)
print(BENCHMARKS)
# Out:
# {'RandomSearch': <class 'lib.optimizers.random_search.RandomSearch'>}
# {'ackley': BenchmarkDescription(name='ackley', load=functools.partial(<bound method FunctionalBenchmark.load of <hpo_glue.benchmark.FunctionalBenchmark object at 0x796f6b9d27a0>>), metrics={'value': Measure(minimize=True, kind=<Kind.METRIC: 'metric'>, bounds=(0.0, inf))}, test_metrics=None, costs=None, fidelities=None, has_conditionals=False, is_tabular=False, env=<bound method Env.empty of <class 'hpo_glue.env.Env'>>, mem_req_mb=100), 'branin': BenchmarkDescription(name='branin', load=functools.partial(<bound method FunctionalBenchmark.load of <hpo_glue.benchmark.FunctionalBenchmark object at 0x796f6b9fd270>>), metrics={'value': Measure(minimize=True, kind=<Kind.METRIC: 'metric'>, bounds=(0.397887, inf))}, test_metrics=None, costs=None, fidelities=None, has_conditionals=False, is_tabular=False, env=<bound method Env.empty of <class 'hpo_glue.env.Env'>>, mem_req_mb=100)}

# %% [markdown]
# ## Select RandomSearch Optimizer and ackley Functional Benchmark

# %%
opt = OPTIMIZERS["RandomSearch"]
bench = BENCHMARKS["ackley"]

# %% [markdown]
# ## Define a Problem with a budget and run hpo_glue with a seed

# %%
from hpo_glue.run_glue import run_glue

result_df = run_glue(
    run_name="hpo_glue_demo",
    optimizer=opt,
    benchmark=bench,
    budget=50,
    seed=0
)

result_df
# Out:
#     budget_cost  budget_used_total  continuations_cost fidelity config_id  \
# 0             1                1.0                 NaN     None         1
# 1             1                2.0                 NaN     None         2
# 2             1                3.0                 NaN     None         3
# 3             1                4.0                 NaN     None         4
# 4             1                5.0                 NaN     None         5
# 5             1                6.0                 NaN     None         6
# 6             1                7.0                 NaN     None         7
# 7             1                8.0                 NaN     None         8
# 8             1                9.0                 NaN     None         9
# 9             1               10.0                 NaN     None        10
# 10            1               11.0                 NaN     None        11
# 11            1               12.0                 NaN     None        12
# 12            1               13.0                 NaN     None        13
# 13            1               14.0                 NaN     None        14
# 14            1               15.0                 NaN     None        15
# 15            1               16.0                 NaN     None        16
# 16            1               17.0                 NaN     None        17
# 17            1               18.0                 NaN     None        18
# 18            1               19.0                 NaN     None        19
# 19            1               20.0                 NaN     None        20
# 20            1               21.0                 NaN     None        21
# 21            1               22.0                 NaN     None        22
# 22            1               23.0                 NaN     None        23
# 23            1               24.0                 NaN     None        24
# 24            1               25.0                 NaN     None        25
# 25            1               26.0                 NaN     None        26
# 26            1               27.0                 NaN     None        27
# 27            1               28.0                 NaN     None        28
# 28            1               29.0                 NaN     None        29
# 29            1               30.0                 NaN     None        30
# 30            1               31.0                 NaN     None        31
# 31            1               32.0                 NaN     None        32
# 32            1               33.0                 NaN     None        33
# 33            1               34.0                 NaN     None        34
# 34            1               35.0                 NaN     None        35
# 35            1               36.0                 NaN     None        36
# 36            1               37.0                 NaN     None        37
# 37            1               38.0                 NaN     None        38
# 38            1               39.0                 NaN     None        39
# 39            1               40.0                 NaN     None        40
# 40            1               41.0                 NaN     None        41
# 41            1               42.0                 NaN     None        42
# 42            1               43.0                 NaN     None        43
# 43            1               44.0                 NaN     None        44
# 44            1               45.0                 NaN     None        45
# 45            1               46.0                 NaN     None        46
# 46            1               47.0                 NaN     None        47
# 47            1               48.0                 NaN     None        48
# 48            1               49.0                 NaN     None        49
# 49            1               50.0                 NaN     None        50
#
#                                               config  \
# 0       {'x0': 3.199041793381, 'x1': 9.561316593936}
# 1     {'x0': 19.118492095786, 'x1': -27.05789421476}
# 2      {'x0': 31.366731676566, 'x1': 9.169864053721}
# 3     {'x0': -15.430083405111, 'x1': 7.709359936365}
# 4     {'x0': -9.207290227996, 'x1': 11.182923423296}
# 5     {'x0': 4.600415546106, 'x1': -22.196419435889}
# 6    {'x0': -22.349769366207, 'x1': -8.603227215563}
# 7    {'x0': 31.225247499118, 'x1': -30.199788846821}
# 8   {'x0': -11.928654355236, 'x1': -15.375434321792}
# 9    {'x0': -11.89026513215, 'x1': -20.762370899502}
# 10     {'x0': 11.653384555478, 'x1': 4.991047068407}
# 11    {'x0': -3.465191186915, 'x1': -6.782599767852}
# 12      {'x0': 14.76226448226, 'x1': 6.972585681088}
# 13       {'x0': 7.734259154868, 'x1': 5.95543728116}
# 14    {'x0': 25.988077705695, 'x1': 13.362042210901}
# 15   {'x0': -22.973755905934, 'x1': 22.807067316862}
# 16    {'x0': 12.938692076802, 'x1': 23.317927847042}
# 17    {'x0': 1.378655024194, 'x1': -18.092871643275}
# 18    {'x0': -21.974603759753, 'x1': 7.468872890181}
# 19    {'x0': -6.670184466606, 'x1': -0.625291518439}
# 20  {'x0': -12.334145077634, 'x1': -28.360728152424}
# 21     {'x0': 32.13485325659, 'x1': 16.933103457805}
# 22      {'x0': 8.45295410159, 'x1': 29.674154031313}
# 23   {'x0': -16.125680510892, 'x1': -4.935813119901}
# 24    {'x0': 23.845640989785, 'x1': -6.811831316821}
# 25   {'x0': -9.462563612265, 'x1': -27.300827270872}
# 26   {'x0': -16.985045079461, 'x1': 18.687781242348}
# 27    {'x0': 31.293121478292, 'x1': 29.446558345834}
# 28  {'x0': -13.564622634497, 'x1': -23.059440536901}
# 29   {'x0': -8.612439252689, 'x1': -18.067159189112}
# 30   {'x0': 26.644021196959, 'x1': -17.548303258685}
# 31   {'x0': 17.732779933878, 'x1': -16.687614535084}
# 32   {'x0': -15.051790402276, 'x1': -2.874371814164}
# 33     {'x0': -20.89609057161, 'x1': 18.18018197332}
# 34   {'x0': -8.463790950456, 'x1': -27.724582290284}
# 35     {'x0': 9.540091540669, 'x1': 11.887739574933}
# 36   {'x0': -20.504189878217, 'x1': -2.712930761534}
# 37   {'x0': 13.082430947362, 'x1': -22.246927729606}
# 38    {'x0': 23.443711209869, 'x1': 26.793981929897}
# 39   {'x0': -28.658043976198, 'x1': 30.079891660045}
# 40    {'x0': -6.471057355335, 'x1': -3.004013156267}
# 41  {'x0': -31.745240960413, 'x1': -16.174861928179}
# 42    {'x0': 31.080855163244, 'x1': -0.635348808582}
# 43   {'x0': -16.946389314662, 'x1': -4.974904053868}
# 44    {'x0': -9.139286147997, 'x1': -9.927434600935}
# 45  {'x0': -13.332888612764, 'x1': -17.470570137643}
# 46  {'x0': -14.913575618743, 'x1': -21.505435300814}
# 47     {'x0': 0.156595486016, 'x1': 16.434125988584}
# 48     {'x0': -28.12347821692, 'x1': 6.823464404312}
# 49  {'x0': -14.757162525157, 'x1': -14.964964222164}
#
#                     result_values  seed     optimizer optimizer_hps benchmark
# 0   {'value': 17.175806745425536}     0  RandomSearch           NaN    ackley
# 1     {'value': 20.2289008503735}     0  RandomSearch           NaN    ackley
# 2    {'value': 21.61077154648434}     0  RandomSearch           NaN    ackley
# 3    {'value': 20.41337202790521}     0  RandomSearch           NaN    ackley
# 4   {'value': 18.738997749537866}     0  RandomSearch           NaN    ackley
# 5   {'value': 21.119969002032654}     0  RandomSearch           NaN    ackley
# 6     {'value': 21.5412736746713}     0  RandomSearch           NaN    ackley
# 7    {'value': 21.41346588813888}     0  RandomSearch           NaN    ackley
# 8   {'value': 20.341531499080656}     0  RandomSearch           NaN    ackley
# 9    {'value': 20.51081643878016}     0  RandomSearch           NaN    ackley
# 10  {'value': 18.149910698317996}     0  RandomSearch           NaN    ackley
# 11    {'value': 15.2273919681294}     0  RandomSearch           NaN    ackley
# 12   {'value': 19.02999974305979}     0  RandomSearch           NaN    ackley
# 13   {'value': 16.15007808961409}     0  RandomSearch           NaN    ackley
# 14  {'value': 21.206254590666855}     0  RandomSearch           NaN    ackley
# 15  {'value': 20.561131394147836}     0  RandomSearch           NaN    ackley
# 16  {'value': 20.965598201377432}     0  RandomSearch           NaN    ackley
# 17    {'value': 20.1243826670248}     0  RandomSearch           NaN    ackley
# 18   {'value': 20.96424353823675}     0  RandomSearch           NaN    ackley
# 19  {'value': 14.411137713439015}     0  RandomSearch           NaN    ackley
# 20  {'value': 21.902177328102432}     0  RandomSearch           NaN    ackley
# 21   {'value': 20.40291128257226}     0  RandomSearch           NaN    ackley
# 22  {'value': 21.970818673371134}     0  RandomSearch           NaN    ackley
# 23  {'value': 18.624176238426855}     0  RandomSearch           NaN    ackley
# 24  {'value': 20.515290743317724}     0  RandomSearch           NaN    ackley
# 25   {'value': 21.85663941698525}     0  RandomSearch           NaN    ackley
# 26   {'value': 20.79621421219257}     0  RandomSearch           NaN    ackley
# 27  {'value': 22.126784476064458}     0  RandomSearch           NaN    ackley
# 28  {'value': 21.257209883540494}     0  RandomSearch           NaN    ackley
# 29  {'value': 20.459893510740105}     0  RandomSearch           NaN    ackley
# 30  {'value': 22.043070710153472}     0  RandomSearch           NaN    ackley
# 31   {'value': 21.29660633736042}     0  RandomSearch           NaN    ackley
# 32  {'value': 18.144151566501087}     0  RandomSearch           NaN    ackley
# 33   {'value': 20.48070355949558}     0  RandomSearch           NaN    ackley
# 34   {'value': 21.81922190588989}     0  RandomSearch           NaN    ackley
# 35  {'value': 19.499970377189403}     0  RandomSearch           NaN    ackley
# 36  {'value': 21.104475116482373}     0  RandomSearch           NaN    ackley
# 37   {'value': 20.63934265967104}     0  RandomSearch           NaN    ackley
# 38   {'value': 21.87111458665634}     0  RandomSearch           NaN    ackley
# 39   {'value': 21.48246362550172}     0  RandomSearch           NaN    ackley
# 40  {'value': 14.418107392114365}     0  RandomSearch           NaN    ackley
# 41  {'value': 21.351945404428744}     0  RandomSearch           NaN    ackley
# 42  {'value': 21.358897090415727}     0  RandomSearch           NaN    ackley
# 43  {'value': 18.446211363905167}     0  RandomSearch           NaN    ackley
# 44  {'value': 17.593251375306885}     0  RandomSearch           NaN    ackley
# 45   {'value': 21.34749966369707}     0  RandomSearch           NaN    ackley
# 46  {'value': 21.293470562030148}     0  RandomSearch           NaN    ackley
# 47  {'value': 19.926609230909392}     0  RandomSearch           NaN    ackley
# 48   {'value': 20.59905213530614}     0  RandomSearch           NaN    ackley
# 49  {'value': 20.028553752524957}     0  RandomSearch           NaN    ackley
