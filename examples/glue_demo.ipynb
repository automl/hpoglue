# %% [markdown]
# # Notebook with minimal example to run hpoglue Optimizers on Benchmarks

# %% [markdown]
# ## Print the list of available example benchmarks and optimizers

# %%
from lib import BENCHMARKS, OPTIMIZERS

print(OPTIMIZERS)
print(BENCHMARKS)
# Out:
# {'RandomSearch': <class 'lib.optimizers.random_search.RandomSearch'>, 'RandomSearchWithPriors': <class 'lib.optimizers.random_search.RandomSearchWithPriors'>}
# {'ackley': <hpoglue.benchmark.FunctionalBenchmark object at 0x70f06c1b0580>, 'branin': <hpoglue.benchmark.FunctionalBenchmark object at 0x70f06c1b1150>}

# %% [markdown]
# ## Select RandomSearch Optimizer and ackley Functional Benchmark

# %%
opt = OPTIMIZERS["RandomSearch"]
bench = BENCHMARKS["ackley"]

# %% [markdown]
# ### Printing Ackley's description

# %%
print(bench.desc)
# Out:
# BenchmarkDescription(name='ackley', config_space=Configuration space object:
#   Hyperparameters:
#     x0, Type: UniformFloat, Range: [-32.768, 32.768], Default: 0.0
#     x1, Type: UniformFloat, Range: [-32.768, 32.768], Default: 0.0
# , load=functools.partial(<bound method FunctionalBenchmark.load of <hpoglue.benchmark.FunctionalBenchmark object at 0x70f06c1b0580>>), metrics={'y': Measure(minimize=True, kind=<Kind.METRIC: 'metric'>, bounds=(0.0, inf))}, test_metrics=None, costs=None, fidelities=None, has_conditionals=False, is_tabular=False, env=Env(name='empty'), mem_req_mb=1024, predefined_points={'min': Config(config_id='min', values={'x0': 0.0, 'x1': 0.0}, description='This point yields a global optimum of y:0.0')}, extra={})

# %% [markdown]
# ## Define a Problem with a budget and run hpoglue with a seed

# %%
from hpoglue.run_glue import run_glue

result_df = run_glue(
    run_name="hpoglue_demo",
    optimizer=opt,
    benchmark=bench,
    objectives="y",
    budget=50,
    seed=1,
)

result_df
# Out:
#     budget_cost  budget_used_total  continuations_cost fidelity config_id  \
# 0             1                1.0                 NaN     None         1
# 1             1                2.0                 NaN     None         2
# 2             1                3.0                 NaN     None         3
# 3             1                4.0                 NaN     None         4
# 4             1                5.0                 NaN     None         5
# 5             1                6.0                 NaN     None         6
# 6             1                7.0                 NaN     None         7
# 7             1                8.0                 NaN     None         8
# 8             1                9.0                 NaN     None         9
# 9             1               10.0                 NaN     None        10
# 10            1               11.0                 NaN     None        11
# 11            1               12.0                 NaN     None        12
# 12            1               13.0                 NaN     None        13
# 13            1               14.0                 NaN     None        14
# 14            1               15.0                 NaN     None        15
# 15            1               16.0                 NaN     None        16
# 16            1               17.0                 NaN     None        17
# 17            1               18.0                 NaN     None        18
# 18            1               19.0                 NaN     None        19
# 19            1               20.0                 NaN     None        20
# 20            1               21.0                 NaN     None        21
# 21            1               22.0                 NaN     None        22
# 22            1               23.0                 NaN     None        23
# 23            1               24.0                 NaN     None        24
# 24            1               25.0                 NaN     None        25
# 25            1               26.0                 NaN     None        26
# 26            1               27.0                 NaN     None        27
# 27            1               28.0                 NaN     None        28
# 28            1               29.0                 NaN     None        29
# 29            1               30.0                 NaN     None        30
# 30            1               31.0                 NaN     None        31
# 31            1               32.0                 NaN     None        32
# 32            1               33.0                 NaN     None        33
# 33            1               34.0                 NaN     None        34
# 34            1               35.0                 NaN     None        35
# 35            1               36.0                 NaN     None        36
# 36            1               37.0                 NaN     None        37
# 37            1               38.0                 NaN     None        38
# 38            1               39.0                 NaN     None        39
# 39            1               40.0                 NaN     None        40
# 40            1               41.0                 NaN     None        41
# 41            1               42.0                 NaN     None        42
# 42            1               43.0                 NaN     None        43
# 43            1               44.0                 NaN     None        44
# 44            1               45.0                 NaN     None        45
# 45            1               46.0                 NaN     None        46
# 46            1               47.0                 NaN     None        47
# 47            1               48.0                 NaN     None        48
# 48            1               49.0                 NaN     None        49
# 49            1               50.0                 NaN     None        50
#
#                                               config  \
# 0    {'x0': -5.438045899812, 'x1': -26.716497853232}
# 1     {'x0': -5.295668304066, 'x1': 11.171758747052}
# 2      {'x0': 19.70959605272, 'x1': 25.860942299388}
# 3   {'x0': -26.322741897917, 'x1': -12.090367606387}
# 4     {'x0': 32.038000322576, 'x1': -3.414849868536}
# 5   {'x0': -31.498767049012, 'x1': -29.270832243207}
# 6      {'x0': -26.06141087234, 'x1': 2.352506858079}
# 7    {'x0': 26.437347920307, 'x1': -21.931347337745}
# 8     {'x0': 25.120347993264, 'x1': 25.944799195697}
# 9   {'x0': -25.248007916528, 'x1': -17.234199822793}
# 10    {'x0': -11.360999717464, 'x1': 8.084528548532}
# 11   {'x0': -21.473492445081, 'x1': 16.742026615355}
# 12    {'x0': -31.465135548675, 'x1': 2.544832632695}
# 13     {'x0': 5.62031961429, 'x1': -17.499797989555}
# 14    {'x0': 3.685759974796, 'x1': -25.723264754903}
# 15    {'x0': -28.05109360627, 'x1': 15.979371172665}
# 16  {'x0': -17.049337256504, 'x1': -31.550590014101}
# 17   {'x0': -11.969337142663, 'x1': 16.078237263888}
# 18     {'x0': 8.501166540165, 'x1': 19.972395089484}
# 19   {'x0': -15.512582849357, 'x1': 28.309721526884}
# 20    {'x0': 29.502742150977, 'x1': -0.918115641137}
# 21     {'x0': -6.889431831442, 'x1': 0.371075689801}
# 22     {'x0': -21.220802194633, 'x1': 28.8428839622}
# 23       {'x0': -2.62928689943, 'x1': 6.49529312188}
# 24    {'x0': -12.108116584342, 'x1': 7.342075218817}
# 25    {'x0': -32.74165289672, 'x1': 21.551238871823}
# 26   {'x0': 16.385426306018, 'x1': -11.620778191307}
# 27     {'x0': -6.45663401774, 'x1': 11.652359221039}
# 28    {'x0': 24.903567839293, 'x1': 23.258591572617}
# 29    {'x0': 1.245946017484, 'x1': -28.297832142163}
# 30    {'x0': 20.437971613813, 'x1': -2.170550828184}
# 31    {'x0': 27.283000752102, 'x1': -0.027251790388}
# 32    {'x0': -5.514938399619, 'x1': -1.498088272706}
# 33   {'x0': -23.29506348239, 'x1': -31.304553071129}
# 34     {'x0': 24.026039855777, 'x1': 9.915880724299}
# 35   {'x0': 17.710365707795, 'x1': -10.138585557167}
# 36    {'x0': -13.090924820306, 'x1': 8.952505958524}
# 37      {'x0': -9.4565059144, 'x1': -8.746231579034}
# 38   {'x0': -3.807361056871, 'x1': -15.586224781858}
# 39   {'x0': -18.876978649912, 'x1': 22.533926350434}
# 40    {'x0': 30.109487665103, 'x1': 29.330567423269}
# 41  {'x0': -25.623346281246, 'x1': -10.324926801935}
# 42  {'x0': -23.368627082347, 'x1': -25.340023749503}
# 43    {'x0': -3.119197274345, 'x1': -6.396803818603}
# 44      {'x0': 7.76690512115, 'x1': 26.568427680745}
# 45    {'x0': -20.471370684666, 'x1': 15.19127161355}
# 46  {'x0': -24.939262749329, 'x1': -12.413353866415}
# 47   {'x0': 26.920408263809, 'x1': -30.739725925014}
# 48        {'x0': -11.40393169584, 'x1': 8.408861083}
# 49      {'x0': 1.13164933537, 'x1': 28.302450139892}
#
#                       results  seed     optimizer optimizer_hps benchmark  \
# 0   {'y': 21.727944700712968}     1  RandomSearch       default    ackley
# 1   {'y': 18.138260403436124}     1  RandomSearch       default    ackley
# 2   {'y': 21.301106057193536}     1  RandomSearch       default    ackley
# 3   {'y': 21.163171636720012}     1  RandomSearch       default    ackley
# 4   {'y': 21.451047172416438}     1  RandomSearch       default    ackley
# 5   {'y': 22.104344895310977}     1  RandomSearch       default    ackley
# 6   {'y': 21.047070833730075}     1  RandomSearch       default    ackley
# 7   {'y': 21.570461484501617}     1  RandomSearch       default    ackley
# 8    {'y': 20.29479781878409}     1  RandomSearch       default    ackley
# 9    {'y': 21.39571827163954}     1  RandomSearch       default    ackley
# 10  {'y': 18.818339395843324}     1  RandomSearch       default    ackley
# 11  {'y': 21.697358526805285}     1  RandomSearch       default    ackley
# 12   {'y': 22.10833222039264}     1  RandomSearch       default    ackley
# 13  {'y': 20.810284950184016}     1  RandomSearch       default    ackley
# 14   {'y': 21.45547893453693}     1  RandomSearch       default    ackley
# 15  {'y': 19.871561298257642}     1  RandomSearch       default    ackley
# 16  {'y': 21.591633894990924}     1  RandomSearch       default    ackley
# 17  {'y': 19.005128875877116}     1  RandomSearch       default    ackley
# 18  {'y': 20.797081693298363}     1  RandomSearch       default    ackley
# 19  {'y': 22.004375477701295}     1  RandomSearch       default    ackley
# 20  {'y': 21.473183456084463}     1  RandomSearch       default    ackley
# 21  {'y': 14.139729220186402}     1  RandomSearch       default    ackley
# 22  {'y': 21.148872431888893}     1  RandomSearch       default    ackley
# 23  {'y': 14.863898136497511}     1  RandomSearch       default    ackley
# 24   {'y': 18.89594594163717}     1  RandomSearch       default    ackley
# 25  {'y': 22.033804980431633}     1  RandomSearch       default    ackley
# 26  {'y': 21.073062201118944}     1  RandomSearch       default    ackley
# 27  {'y': 19.215263745946732}     1  RandomSearch       default    ackley
# 28  {'y': 21.088618928722937}     1  RandomSearch       default    ackley
# 29   {'y': 21.48061665216652}     1  RandomSearch       default    ackley
# 30  {'y': 20.825080145553116}     1  RandomSearch       default    ackley
# 31   {'y': 20.81962924030579}     1  RandomSearch       default    ackley
# 32  {'y': 13.436327481406206}     1  RandomSearch       default    ackley
# 33  {'y': 21.902925686358714}     1  RandomSearch       default    ackley
# 34    {'y': 19.6895901250264}     1  RandomSearch       default    ackley
# 35  {'y': 20.382246024688047}     1  RandomSearch       default    ackley
# 36  {'y': 18.139257936595552}     1  RandomSearch       default    ackley
# 37  {'y': 18.872519823850052}     1  RandomSearch       default    ackley
# 38   {'y': 19.87285719592716}     1  RandomSearch       default    ackley
# 39   {'y': 21.52783047389868}     1  RandomSearch       default    ackley
# 40  {'y': 21.511175414854865}     1  RandomSearch       default    ackley
# 41  {'y': 21.758528758029914}     1  RandomSearch       default    ackley
# 42   {'y': 22.02062484415786}     1  RandomSearch       default    ackley
# 43   {'y': 14.43990183449818}     1  RandomSearch       default    ackley
# 44   {'y': 21.64998773814285}     1  RandomSearch       default    ackley
# 45  {'y': 21.442327545215807}     1  RandomSearch       default    ackley
# 46  {'y': 21.292214713102428}     1  RandomSearch       default    ackley
# 47   {'y': 21.15484795980676}     1  RandomSearch       default    ackley
# 48  {'y': 19.586583548167244}     1  RandomSearch       default    ackley
# 49  {'y': 21.160841927583487}     1  RandomSearch       default    ackley
#
#    objectives fidelities costs
# 0           y       None  None
# 1           y       None  None
# 2           y       None  None
# 3           y       None  None
# 4           y       None  None
# 5           y       None  None
# 6           y       None  None
# 7           y       None  None
# 8           y       None  None
# 9           y       None  None
# 10          y       None  None
# 11          y       None  None
# 12          y       None  None
# 13          y       None  None
# 14          y       None  None
# 15          y       None  None
# 16          y       None  None
# 17          y       None  None
# 18          y       None  None
# 19          y       None  None
# 20          y       None  None
# 21          y       None  None
# 22          y       None  None
# 23          y       None  None
# 24          y       None  None
# 25          y       None  None
# 26          y       None  None
# 27          y       None  None
# 28          y       None  None
# 29          y       None  None
# 30          y       None  None
# 31          y       None  None
# 32          y       None  None
# 33          y       None  None
# 34          y       None  None
# 35          y       None  None
# 36          y       None  None
# 37          y       None  None
# 38          y       None  None
# 39          y       None  None
# 40          y       None  None
# 41          y       None  None
# 42          y       None  None
# 43          y       None  None
# 44          y       None  None
# 45          y       None  None
# 46          y       None  None
# 47          y       None  None
# 48          y       None  None
# 49          y       None  None

# %% [markdown]
# ## RandomSearch With Priors on Ackley

# %%
opt = OPTIMIZERS["RandomSearchWithPriors"]
bench = BENCHMARKS["ackley"]

# %%
from hpoglue.run_glue import run_glue

result_df = run_glue(
    run_name="hpoglue_demo",
    optimizer=opt,
    benchmark=bench,
    objectives="y",
    budget=50,
    seed=1,
    priors={
        "y": {
            "x0": 0,
            "x1": 1,
        }
    }
)

result_df
# Out:
#     budget_cost  budget_used_total  continuations_cost fidelity config_id  \
# 0             1                1.0                 NaN     None         1
# 1             1                2.0                 NaN     None         2
# 2             1                3.0                 NaN     None         3
# 3             1                4.0                 NaN     None         4
# 4             1                5.0                 NaN     None         5
# 5             1                6.0                 NaN     None         6
# 6             1                7.0                 NaN     None         7
# 7             1                8.0                 NaN     None         8
# 8             1                9.0                 NaN     None         9
# 9             1               10.0                 NaN     None        10
# 10            1               11.0                 NaN     None        11
# 11            1               12.0                 NaN     None        12
# 12            1               13.0                 NaN     None        13
# 13            1               14.0                 NaN     None        14
# 14            1               15.0                 NaN     None        15
# 15            1               16.0                 NaN     None        16
# 16            1               17.0                 NaN     None        17
# 17            1               18.0                 NaN     None        18
# 18            1               19.0                 NaN     None        19
# 19            1               20.0                 NaN     None        20
# 20            1               21.0                 NaN     None        21
# 21            1               22.0                 NaN     None        22
# 22            1               23.0                 NaN     None        23
# 23            1               24.0                 NaN     None        24
# 24            1               25.0                 NaN     None        25
# 25            1               26.0                 NaN     None        26
# 26            1               27.0                 NaN     None        27
# 27            1               28.0                 NaN     None        28
# 28            1               29.0                 NaN     None        29
# 29            1               30.0                 NaN     None        30
# 30            1               31.0                 NaN     None        31
# 31            1               32.0                 NaN     None        32
# 32            1               33.0                 NaN     None        33
# 33            1               34.0                 NaN     None        34
# 34            1               35.0                 NaN     None        35
# 35            1               36.0                 NaN     None        36
# 36            1               37.0                 NaN     None        37
# 37            1               38.0                 NaN     None        38
# 38            1               39.0                 NaN     None        39
# 39            1               40.0                 NaN     None        40
# 40            1               41.0                 NaN     None        41
# 41            1               42.0                 NaN     None        42
# 42            1               43.0                 NaN     None        43
# 43            1               44.0                 NaN     None        44
# 44            1               45.0                 NaN     None        45
# 45            1               46.0                 NaN     None        46
# 46            1               47.0                 NaN     None        47
# 47            1               48.0                 NaN     None        48
# 48            1               49.0                 NaN     None        49
# 49            1               50.0                 NaN     None        50
#
#                                            config                    results  \
# 0   {'x0': -0.052379460229, 'x1': 0.668377306833}  {'y': 3.2715387622416974}
# 1    {'x0': -0.05098863345, 'x1': 1.110301116742}   {'y': 3.266076165339762}
# 2    {'x0': 0.211070938288, 'x1': 1.312851305538}   {'y': 5.215603455586482}
# 3     {'x0': -0.3227572169, 'x1': 0.879931038656}   {'y': 4.046597364705523}
# 4    {'x0': 0.571399351007, 'x1': 0.967253711736}    {'y': 4.61653936871226}
# 5   {'x0': -0.516750632023, 'x1': 0.596727654362}   {'y': 4.427411585093363}
# 6   {'x0': -0.317090393341, 'x1': 1.022525176509}   {'y': 4.191227256105709}
# 7    {'x0': 0.325295496771, 'x1': 0.756828001579}   {'y': 4.104143948419296}
# 8    {'x0': 0.297919315178, 'x1': 1.314613534305}   {'y': 5.481795720525124}
# 9   {'x0': -0.300417153542, 'x1': 0.821025348988}  {'y': 3.9824252331169245}
# 10  {'x0': -0.112299162623, 'x1': 1.078579421012}  {'y': 3.2893022722690657}
# 11  {'x0': -0.236239158244, 'x1': 1.172945638274}   {'y': 4.513938388065718}
# 12   {'x0': -0.51405771851, 'x1': 1.024372312345}   {'y': 4.714815286767596}
# 13   {'x0': 0.054162390803, 'x1': 0.817728291481}   {'y': 2.937540609687972}
# 14    {'x0': 0.03536089387, 'x1': 0.690008694695}  {'y': 3.2252189251782437}
# 15   {'x0': -0.365310938563, 'x1': 1.16379638937}   {'y': 4.958151478178063}
# 16  {'x0': -0.176698091919, 'x1': 0.478978662392}   {'y': 3.350611296509648}
# 17  {'x0': -0.118771800996, 'x1': 1.164969883729}   {'y': 3.908552800046405}
# 18   {'x0': 0.082776312572, 'x1': 1.214681875994}    {'y': 4.15896835819575}
# 19  {'x0': -0.158303639204, 'x1': 1.372660166509}   {'y': 5.341446168070394}
# 20   {'x0': 0.411640919334, 'x1': 0.991219147421}    {'y': 4.45768724381556}
# 21     {'x0': -0.0666584185, 'x1': 1.00354835528}  {'y': 2.7669643829305923}
# 22  {'x0': -0.232489654376, 'x1': 1.388919127183}  {'y': 5.6096036927586574}
# 23   {'x0': -0.025183842922, 'x1': 1.06276122842}   {'y': 2.910307964138305}
# 24   {'x0': -0.120259459648, 'x1': 1.07115423032}  {'y': 3.2873148524478535}
# 25  {'x0': -0.837849219922, 'x1': 1.237403518754}   {'y': 5.176074745413015}
# 26    {'x0': 0.168639559804, 'x1': 0.88494628078}   {'y': 3.252590915256079}
# 27   {'x0': -0.062379807786, 'x1': 1.11538953566}  {'y': 3.3331740850542215}
# 28   {'x0': 0.293744559164, 'x1': 1.264418487986}    {'y': 5.23805260884421}
# 29   {'x0': 0.011918283701, 'x1': 0.627684791372}   {'y': 3.254352625614857}
# 30   {'x0': 0.221191614047, 'x1': 0.979221233238}  {'y': 3.5690200184792187}
# 31   {'x0': 0.345160637926, 'x1': 0.999739417569}   {'y': 4.252523277499765}
# 32  {'x0': -0.053131262661, 'x1': 0.985667390468}   {'y': 2.685182973533689}
# 33  {'x0': -0.265029411847, 'x1': 0.498041315276}  {'y': 3.6733724105046126}
# 34   {'x0': 0.277625102423, 'x1': 1.097211072502}   {'y': 4.294812445768628}
# 35   {'x0': 0.184908324723, 'x1': 0.900488040446}    {'y': 3.32659547724483}
# 36   {'x0': -0.130921599034, 'x1': 1.08734927839}  {'y': 3.4353056299547338}
# 37  {'x0': -0.092490655113, 'x1': 0.914744225922}   {'y': 2.822099096485108}
# 38  {'x0': -0.036535731065, 'x1': 0.840834936231}  {'y': 2.8306686251954187}
# 39  {'x0': -0.199909601342, 'x1': 1.252591932694}   {'y': 4.844669451531534}
# 40   {'x0': 0.436039765086, 'x1': 1.405384721655}   {'y': 6.058612186153127}
# 41    {'x0': -0.307940817149, 'x1': 0.8985563556}   {'y': 3.981443427546829}
# 42  {'x0': -0.266266481525, 'x1': 0.697763664953}   {'y': 3.914127412483332}
# 43  {'x0': -0.029896959802, 'x1': 0.938210206514}  {'y': 2.6085520114712506}
# 44   {'x0': 0.075394799989, 'x1': 1.328240366887}    {'y': 4.91602523142129}
# 45  {'x0': -0.221664365978, 'x1': 1.154566814269}   {'y': 4.333031076405224}
# 46   {'x0': -0.29442633289, 'x1': 0.876453385827}  {'y': 3.9248108024400534}
# 47   {'x0': 0.336382346843, 'x1': 0.533243599238}   {'y': 3.950746969030114}
# 48  {'x0': -0.112753442859, 'x1': 1.081844526118}   {'y': 3.310618692976839}
# 49   {'x0': 0.010824243614, 'x1': 1.372449110714}   {'y': 5.083765651034248}
#
#     seed               optimizer optimizer_hps benchmark objectives  \
# 0      1  RandomSearchWithPriors       default    ackley          y
# 1      1  RandomSearchWithPriors       default    ackley          y
# 2      1  RandomSearchWithPriors       default    ackley          y
# 3      1  RandomSearchWithPriors       default    ackley          y
# 4      1  RandomSearchWithPriors       default    ackley          y
# 5      1  RandomSearchWithPriors       default    ackley          y
# 6      1  RandomSearchWithPriors       default    ackley          y
# 7      1  RandomSearchWithPriors       default    ackley          y
# 8      1  RandomSearchWithPriors       default    ackley          y
# 9      1  RandomSearchWithPriors       default    ackley          y
# 10     1  RandomSearchWithPriors       default    ackley          y
# 11     1  RandomSearchWithPriors       default    ackley          y
# 12     1  RandomSearchWithPriors       default    ackley          y
# 13     1  RandomSearchWithPriors       default    ackley          y
# 14     1  RandomSearchWithPriors       default    ackley          y
# 15     1  RandomSearchWithPriors       default    ackley          y
# 16     1  RandomSearchWithPriors       default    ackley          y
# 17     1  RandomSearchWithPriors       default    ackley          y
# 18     1  RandomSearchWithPriors       default    ackley          y
# 19     1  RandomSearchWithPriors       default    ackley          y
# 20     1  RandomSearchWithPriors       default    ackley          y
# 21     1  RandomSearchWithPriors       default    ackley          y
# 22     1  RandomSearchWithPriors       default    ackley          y
# 23     1  RandomSearchWithPriors       default    ackley          y
# 24     1  RandomSearchWithPriors       default    ackley          y
# 25     1  RandomSearchWithPriors       default    ackley          y
# 26     1  RandomSearchWithPriors       default    ackley          y
# 27     1  RandomSearchWithPriors       default    ackley          y
# 28     1  RandomSearchWithPriors       default    ackley          y
# 29     1  RandomSearchWithPriors       default    ackley          y
# 30     1  RandomSearchWithPriors       default    ackley          y
# 31     1  RandomSearchWithPriors       default    ackley          y
# 32     1  RandomSearchWithPriors       default    ackley          y
# 33     1  RandomSearchWithPriors       default    ackley          y
# 34     1  RandomSearchWithPriors       default    ackley          y
# 35     1  RandomSearchWithPriors       default    ackley          y
# 36     1  RandomSearchWithPriors       default    ackley          y
# 37     1  RandomSearchWithPriors       default    ackley          y
# 38     1  RandomSearchWithPriors       default    ackley          y
# 39     1  RandomSearchWithPriors       default    ackley          y
# 40     1  RandomSearchWithPriors       default    ackley          y
# 41     1  RandomSearchWithPriors       default    ackley          y
# 42     1  RandomSearchWithPriors       default    ackley          y
# 43     1  RandomSearchWithPriors       default    ackley          y
# 44     1  RandomSearchWithPriors       default    ackley          y
# 45     1  RandomSearchWithPriors       default    ackley          y
# 46     1  RandomSearchWithPriors       default    ackley          y
# 47     1  RandomSearchWithPriors       default    ackley          y
# 48     1  RandomSearchWithPriors       default    ackley          y
# 49     1  RandomSearchWithPriors       default    ackley          y
#
#    fidelities costs
# 0        None  None
# 1        None  None
# 2        None  None
# 3        None  None
# 4        None  None
# 5        None  None
# 6        None  None
# 7        None  None
# 8        None  None
# 9        None  None
# 10       None  None
# 11       None  None
# 12       None  None
# 13       None  None
# 14       None  None
# 15       None  None
# 16       None  None
# 17       None  None
# 18       None  None
# 19       None  None
# 20       None  None
# 21       None  None
# 22       None  None
# 23       None  None
# 24       None  None
# 25       None  None
# 26       None  None
# 27       None  None
# 28       None  None
# 29       None  None
# 30       None  None
# 31       None  None
# 32       None  None
# 33       None  None
# 34       None  None
# 35       None  None
# 36       None  None
# 37       None  None
# 38       None  None
# 39       None  None
# 40       None  None
# 41       None  None
# 42       None  None
# 43       None  None
# 44       None  None
# 45       None  None
# 46       None  None
# 47       None  None
# 48       None  None
# 49       None  None
